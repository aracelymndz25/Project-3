# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree

# %%
lending_data = pd.read_csv("LoanStats_2019Q1.csv")

# %%
lending_data.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    20000.0      20000.0          20000.0   60 months
# 1  NaN        NaN    12000.0      12000.0          12000.0   36 months
# 2  NaN        NaN     3000.0       3000.0           3000.0   36 months
# 3  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 4  NaN        NaN     5000.0       5000.0           5000.0   36 months
#
#   int_rate  installment grade sub_grade  ...  \
# 0   17.19%       499.10     C        C5  ...
# 1   16.40%       424.26     C        C4  ...
# 2   14.74%       103.62     C        C2  ...
# 3   15.57%      1223.08     C        C3  ...
# 4   15.57%       174.73     C        C3  ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#   hardship_last_payment_amount  debt_settlement_flag  \
# 0                          NaN                     N
# 1                          NaN                     N
# 2                          NaN                     N
# 3                          NaN                     N
# 4                          NaN                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount  settlement_percentage  settlement_term
# 0               NaN                    NaN              NaN
# 1               NaN                    NaN              NaN
# 2               NaN                    NaN              NaN
# 3               NaN                    NaN              NaN
# 4               NaN                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
print(lending_data.keys())
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=144)

# %%
lending_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115679 entries, 0 to 115678
# Columns: 144 entries, id to settlement_term
# dtypes: float64(107), object(37)
# memory usage: 127.1+ MB

# %%
lending_data.describe()
# Out:
#        member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count        0.0  115675.000000  115675.000000    115675.000000
# mean         NaN   16671.263021   16671.263021     16668.042144
# std          NaN   10352.132790   10352.132790     10354.685658
# min          NaN    1000.000000    1000.000000       725.000000
# 25%          NaN    9000.000000    9000.000000      9000.000000
# 50%          NaN   15000.000000   15000.000000     15000.000000
# 75%          NaN   24000.000000   24000.000000     24000.000000
# max          NaN   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc  url  desc            dti    delinq_2yrs  \
# count  115675.000000  1.156750e+05  0.0   0.0  115418.000000  115675.000000
# mean      481.083874  8.505333e+04  NaN   NaN      20.445427       0.227595
# std       290.651469  1.098949e+05  NaN   NaN      20.480562       0.746965
# min        30.640000  0.000000e+00  NaN   NaN       0.000000       0.000000
# 25%       264.940000  4.900000e+04  NaN   NaN      12.210000       0.000000
# 50%       401.530000  7.000000e+04  NaN   NaN      18.480000       0.000000
# 75%       648.100000  1.000000e+05  NaN   NaN      25.790000       0.000000
# max      1676.230000  9.000000e+06  NaN   NaN     999.000000      21.000000
#
#        ...  deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# count  ...            1.0             1.00              1.0           1.0
# mean   ...            3.0            35.21              3.0          11.0
# std    ...            NaN              NaN              NaN           NaN
# min    ...            3.0            35.21              3.0          11.0
# 25%    ...            3.0            35.21              3.0          11.0
# 50%    ...            3.0            35.21              3.0          11.0
# 75%    ...            3.0            35.21              3.0          11.0
# max    ...            3.0            35.21              3.0          11.0
#
#        orig_projected_additional_accrued_interest  \
# count                                        1.00
# mean                                       105.63
# std                                           NaN
# min                                        105.63
# 25%                                        105.63
# 50%                                        105.63
# 75%                                        105.63
# max                                        105.63
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                            1.00                           1.0
# mean                          5636.06                           5.9
# std                               NaN                           NaN
# min                           5636.06                           5.9
# 25%                           5636.06                           5.9
# 50%                           5636.06                           5.9
# 75%                           5636.06                           5.9
# max                           5636.06                           5.9
#
#        settlement_amount  settlement_percentage  settlement_term
# count                1.0                    1.0              1.0
# mean              2839.0                   65.0             18.0
# std                  NaN                    NaN              NaN
# min               2839.0                   65.0             18.0
# 25%               2839.0                   65.0             18.0
# 50%               2839.0                   65.0             18.0
# 75%               2839.0                   65.0             18.0
# max               2839.0                   65.0             18.0
#
# [8 rows x 107 columns]

# %%
lending_data.isnull().values.any()
lending_data.isnull().sum()
# Out:
# id                                            115677
# member_id                                     115679
# loan_amnt                                          4
# funded_amnt                                        4
# funded_amnt_inv                                    4
# term                                               4
# int_rate                                           4
# installment                                        4
# grade                                              4
# sub_grade                                          4
# emp_title                                      19522
# emp_length                                     11105
# home_ownership                                     4
# annual_inc                                         4
# verification_status                                4
# issue_d                                            4
# loan_status                                        4
# pymnt_plan                                         4
# url                                           115679
# desc                                          115679
# purpose                                            4
# title                                              4
# zip_code                                           4
# addr_state                                         4
# dti                                              261
# delinq_2yrs                                        4
# earliest_cr_line                                   4
# inq_last_6mths                                     4
# mths_since_last_delinq                         65803
# mths_since_last_record                        102256
#                                                ...
# sec_app_mort_acc                               98998
# sec_app_open_acc                               98998
# sec_app_revol_util                             99228
# sec_app_open_act_il                            98998
# sec_app_num_rev_accts                          98998
# sec_app_chargeoff_within_12_mths               98998
# sec_app_collections_12_mths_ex_med             98998
# sec_app_mths_since_last_major_derog           110778
# hardship_flag                                      4
# hardship_type                                 115678
# hardship_reason                               115678
# hardship_status                               115678
# deferral_term                                 115678
# hardship_amount                               115678
# hardship_start_date                           115678
# hardship_end_date                             115678
# payment_plan_start_date                       115678
# hardship_length                               115678
# hardship_dpd                                  115678
# hardship_loan_status                          115678
# orig_projected_additional_accrued_interest    115678
# hardship_payoff_balance_amount                115678
# hardship_last_payment_amount                  115678
# debt_settlement_flag                               4
# debt_settlement_flag_date                     115678
# settlement_status                             115678
# settlement_date                               115678
# settlement_amount                             115678
# settlement_percentage                         115678
# settlement_term                               115678
# Length: 144, dtype: int64

# %%
print(lending_data.tail())
# Out:
#                                                       id  member_id  \
# 115674                                               NaN        NaN
# 115675                                               NaN        NaN
# 115676                                               NaN        NaN
# 115677  Total amount funded in policy code 1: 1928448350        NaN
# 115678   Total amount funded in policy code 2: 799372035        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 115674    29250.0      29250.0          29250.0   60 months   18.94%
# 115675        NaN          NaN              NaN         NaN      NaN
# 115676        NaN          NaN              NaN         NaN      NaN
# 115677        NaN          NaN              NaN         NaN      NaN
# 115678        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade  ...  \
# 115674        757.8     D        D2  ...
# 115675          NaN   NaN       NaN  ...
# 115676          NaN   NaN       NaN  ...
# 115677          NaN   NaN       NaN  ...
# 115678          NaN   NaN       NaN  ...
#
#        orig_projected_additional_accrued_interest  \
# 115674                                        NaN
# 115675                                        NaN
# 115676                                        NaN
# 115677                                        NaN
# 115678                                        NaN
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 115674                            NaN                          NaN
# 115675                            NaN                          NaN
# 115676                            NaN                          NaN
# 115677                            NaN                          NaN
# 115678                            NaN                          NaN
#
#         debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 115674                     N                       NaN               NaN
# 115675                   NaN                       NaN               NaN
# 115676                   NaN                       NaN               NaN
# 115677                   NaN                       NaN               NaN
# 115678                   NaN                       NaN               NaN
#
#        settlement_date settlement_amount  settlement_percentage  \
# 115674             NaN               NaN                    NaN
# 115675             NaN               NaN                    NaN
# 115676             NaN               NaN                    NaN
# 115677             NaN               NaN                    NaN
# 115678             NaN               NaN                    NaN
#
#         settlement_term
# 115674              NaN
# 115675              NaN
# 115676              NaN
# 115677              NaN
# 115678              NaN
#
# [5 rows x 144 columns]

# %%
lending_data = lending_data

# Inspect the shape
print(lending_data.shape)
# Out:
# (115679, 144)

# %%
lending_data["int_rate"]=lending_data["int_rate"].str.replace(r"%","")
lending_data["revol_util"]=lending_data["revol_util"].str.replace(r"%","")
# lending_data["zip_code"]=lending_data["zip_code"].str.replace(r"xx","")
lending_data.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    20000.0      20000.0          20000.0   60 months
# 1  NaN        NaN    12000.0      12000.0          12000.0   36 months
# 2  NaN        NaN     3000.0       3000.0           3000.0   36 months
# 3  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 4  NaN        NaN     5000.0       5000.0           5000.0   36 months
#
#   int_rate  installment grade sub_grade  ...  \
# 0    17.19       499.10     C        C5  ...
# 1    16.40       424.26     C        C4  ...
# 2    14.74       103.62     C        C2  ...
# 3    15.57      1223.08     C        C3  ...
# 4    15.57       174.73     C        C3  ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#   hardship_last_payment_amount  debt_settlement_flag  \
# 0                          NaN                     N
# 1                          NaN                     N
# 2                          NaN                     N
# 3                          NaN                     N
# 4                          NaN                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount  settlement_percentage  settlement_term
# 0               NaN                    NaN              NaN
# 1               NaN                    NaN              NaN
# 2               NaN                    NaN              NaN
# 3               NaN                    NaN              NaN
# 4               NaN                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
lending_df = lending_data[["loan_status", "loan_amnt", "int_rate",'grade', "annual_inc","dti", "delinq_2yrs", "inq_last_6mths", "open_acc", "pub_rec", "revol_bal", "revol_util", "total_acc"]]
status = lending_df.groupby("loan_status").count()
status
# Out:
#                     loan_amnt  int_rate   grade  annual_inc     dti  \
# loan_status
# Charged Off               176       176     176         176     176
# Current                109176    109176  109176      109176  108936
# Fully Paid               4730      4730    4730        4730    4716
# In Grace Period           538       538     538         538     537
# Late (16-30 days)         260       260     260         260     259
# Late (31-120 days)        795       795     795         795     794
#
#                     delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# loan_status
# Charged Off                 176             176       176      176        176
# Current                  109176          109176    109176   109176     109176
# Fully Paid                 4730            4730      4730     4730       4730
# In Grace Period             538             538       538      538        538
# Late (16-30 days)           260             260       260      260        260
# Late (31-120 days)          795             795       795      795        795
#
#                     revol_util  total_acc
# loan_status
# Charged Off                173        176
# Current                 109063     109176
# Fully Paid                4719       4730
# In Grace Period            538        538
# Late (16-30 days)          260        260
# Late (31-120 days)         793        795

# %%
status.describe()
# Out:
#            loan_amnt       int_rate          grade     annual_inc  \
# count       6.000000       6.000000       6.000000       6.000000
# mean    19279.166667   19279.166667   19279.166667   19279.166667
# std     44074.197252   44074.197252   44074.197252   44074.197252
# min       176.000000     176.000000     176.000000     176.000000
# 25%       329.500000     329.500000     329.500000     329.500000
# 50%       666.500000     666.500000     666.500000     666.500000
# 75%      3746.250000    3746.250000    3746.250000    3746.250000
# max    109176.000000  109176.000000  109176.000000  109176.000000
#
#                  dti    delinq_2yrs  inq_last_6mths       open_acc  \
# count       6.000000       6.000000        6.000000       6.000000
# mean    19236.333333   19279.166667    19279.166667   19279.166667
# std     43977.472627   44074.197252    44074.197252   44074.197252
# min       176.000000     176.000000      176.000000     176.000000
# 25%       328.500000     329.500000      329.500000     329.500000
# 50%       665.500000     666.500000      666.500000     666.500000
# 75%      3735.500000    3746.250000     3746.250000    3746.250000
# max    108936.000000  109176.000000   109176.000000  109176.000000
#
#              pub_rec      revol_bal     revol_util      total_acc
# count       6.000000       6.000000       6.000000       6.000000
# mean    19279.166667   19279.166667   19257.666667   19279.166667
# std     44074.197252   44074.197252   44029.254818   44074.197252
# min       176.000000     176.000000     173.000000     176.000000
# 25%       329.500000     329.500000     329.500000     329.500000
# 50%       666.500000     666.500000     665.500000     666.500000
# 75%      3746.250000    3746.250000    3737.500000    3746.250000
# max    109176.000000  109176.000000  109063.000000  109176.000000

# %%
status.isnull().values.any()
status.isnull().sum()
# Out:
# loan_amnt         0
# int_rate          0
# grade             0
# annual_inc        0
# dti               0
# delinq_2yrs       0
# inq_last_6mths    0
# open_acc          0
# pub_rec           0
# revol_bal         0
# revol_util        0
# total_acc         0
# dtype: int64

# %%
#Create the upsample and downsample
small_sample = lending_df[(lending_df["loan_status"] == "Charged Off") | (lending_df["loan_status"] == "Late (31-120 days)")]
large_sample = lending_df[(lending_df["loan_status"] == "Fully Paid")]

# %%
small_sample.head()
large_sample.head()
# Out:
#     loan_status  loan_amnt int_rate grade  annual_inc    dti  delinq_2yrs  \
# 64   Fully Paid    25200.0    15.57     C     65000.0  15.18          0.0
# 87   Fully Paid    17500.0    17.19     C     82000.0  15.70          1.0
# 91   Fully Paid    10000.0    13.90     C     90000.0   7.92          0.0
# 105  Fully Paid    13750.0    28.80     D     17808.0  30.12          0.0
# 133  Fully Paid    10000.0    12.40     B     38000.0  38.66          0.0
#
#      inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc
# 64              0.0       4.0      0.0    17271.0      78.50       16.0
# 87              0.0      12.0      0.0    15296.0      83.60       27.0
# 91              1.0       5.0      0.0     9898.0      58.60        6.0
# 105             2.0       6.0      0.0    16814.0      87.60        8.0
# 133             0.0       7.0      0.0     8334.0         49       18.0

# %%
small_sample = small_sample.dropna()

# %%
large_sample = large_sample.dropna()

# %%
small_sample.isnull().values.any()
large_sample.isnull().sum()
# Out:
# loan_status       0
# loan_amnt         0
# int_rate          0
# grade             0
# annual_inc        0
# dti               0
# delinq_2yrs       0
# inq_last_6mths    0
# open_acc          0
# pub_rec           0
# revol_bal         0
# revol_util        0
# total_acc         0
# dtype: int64

# %%
n_class0 = len(small_sample)
n_class1 = len(large_sample)

under = large_sample.sample(n_class0)
sample_df = pd.concat([under, small_sample], axis=0)

len(sample_df)
# Out:
# 1930

# %%
X = sample_df[["loan_status", "loan_amnt", "int_rate",'grade', "annual_inc","dti", "delinq_2yrs", "inq_last_6mths", "open_acc", "pub_rec", "revol_bal", "revol_util", "total_acc"]]
y = sample_df["loan_status"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (1930, 13) (1930, 1)

# %%
sample_df["loan_category"] = np.where(sample_df["loan_status"] == "Fully Paid", 1, 0)
sample_df.head()
# Out:
#        loan_status  loan_amnt int_rate grade  annual_inc    dti  delinq_2yrs  \
# 101062  Fully Paid     3000.0    10.33     B     22000.0   4.80          0.0
# 113809  Fully Paid    40000.0    10.33     B    102000.0  11.32          0.0
# 32145   Fully Paid    13500.0     8.81     A     49500.0  13.14          0.0
# 76327   Fully Paid    22000.0     8.19     A    148000.0  16.95          0.0
# 34016   Fully Paid    40000.0    15.57     C    118000.0  10.74          0.0
#
#         inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 101062             1.0       5.0      0.0     3322.0      21.30        8.0
# 113809             0.0      23.0      1.0      991.0       2.50       46.0
# 32145              0.0      23.0      0.0     4566.0      14.80       34.0
# 76327              0.0       7.0      0.0    14619.0      69.30       19.0
# 34016              0.0       7.0      0.0     4423.0      19.80       19.0
#
#         loan_category
# 101062              1
# 113809              1
# 32145               1
# 76327               1
# 34016               1

# %%
data_binary_encoded = pd.get_dummies(sample_df, columns=["loan_status"])
data_binary_encoded.head()
# Out:
#         loan_amnt int_rate grade  annual_inc    dti  delinq_2yrs  \
# 101062     3000.0    10.33     B     22000.0   4.80          0.0
# 113809    40000.0    10.33     B    102000.0  11.32          0.0
# 32145     13500.0     8.81     A     49500.0  13.14          0.0
# 76327     22000.0     8.19     A    148000.0  16.95          0.0
# 34016     40000.0    15.57     C    118000.0  10.74          0.0
#
#         inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 101062             1.0       5.0      0.0     3322.0      21.30        8.0
# 113809             0.0      23.0      1.0      991.0       2.50       46.0
# 32145              0.0      23.0      0.0     4566.0      14.80       34.0
# 76327              0.0       7.0      0.0    14619.0      69.30       19.0
# 34016              0.0       7.0      0.0     4423.0      19.80       19.0
#
#         loan_category  loan_status_Charged Off  loan_status_Fully Paid  \
# 101062              1                        0                       1
# 113809              1                        0                       1
# 32145               1                        0                       1
# 76327               1                        0                       1
# 34016               1                        0                       1
#
#         loan_status_Late (31-120 days)
# 101062                               0
# 113809                               0
# 32145                                0
# 76327                                0
# 34016                                0

# %%
# sample_df["loan_category"] = np.where(sample_df["loan_status"] == "Fully Paid", 1, 0)
# sample_df.head()

# %%
data = sample_df.drop("loan_status", axis=1)
feature_names = data.columns
data.head()
# Out:
#         loan_amnt int_rate grade  annual_inc    dti  delinq_2yrs  \
# 101062     3000.0    10.33     B     22000.0   4.80          0.0
# 113809    40000.0    10.33     B    102000.0  11.32          0.0
# 32145     13500.0     8.81     A     49500.0  13.14          0.0
# 76327     22000.0     8.19     A    148000.0  16.95          0.0
# 34016     40000.0    15.57     C    118000.0  10.74          0.0
#
#         inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 101062             1.0       5.0      0.0     3322.0      21.30        8.0
# 113809             0.0      23.0      1.0      991.0       2.50       46.0
# 32145              0.0      23.0      0.0     4566.0      14.80       34.0
# 76327              0.0       7.0      0.0    14619.0      69.30       19.0
# 34016              0.0       7.0      0.0     4423.0      19.80       19.0
#
#         loan_category
# 101062              1
# 113809              1
# 32145               1
# 76327               1
# 34016               1

# %%
# import seaborn as sns
# sns.pairplot(data)

# %%
#2/3 YOUR ORIGINAL DATA SET AS THE TRAINING SET
#1/3 remains will compose the test set.
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)#EXPLIT THE DATA IN TO ???

# %%
clf = tree.DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-d5619cb7c273> in <module>
#       2
#       3 # Train Decision Tree Classifer
# ----> 4 clf = clf.fit(X_train,y_train)
#       5 clf.score(X_test, y_test)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Late (31-120 days)'

# %%
# Print the r2 score for the test data
# YOUR CODE HERE
print(f"Training Data Score: {clf.score(X_train, y_train)}")
print(f"Testing Data Score: {clf.score(X_test, y_test)}")

# %%
clusters = clf.predict(X_test)
clusters

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200) #n_estimator is number of tree to be used in the forest
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)

# %%
importances = rf.feature_importances_
importances

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)

# %%
import seaborn as sns
sns.heatmap(data.corr(), annot=True)
